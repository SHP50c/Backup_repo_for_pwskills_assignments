# %% [markdown]
# Q1. How can you create a Bokeh plot using Python code?
# ans: below code is used in python to create a Bokeh plot
#
# below line is used to install bokeh in local
#
# !pip install bokeh
#
# below line is used to import bokeh library
#
# import bokeh.io
#
# below line is used to import plotting library from bokeh
#
# import bokeh.plotting
#
# below line is used to show the plot in the notebook
#
# bokeh.io.output_notebook()
#
# below line is used to import the figure and the output file
#
# from bokeh.plotting import figure,output_file,show
#
# below line is used to import the sample dataset
#
# from bokeh.sampledata.iris import flowers
#
# below line is used to name the file
#
# output_file('test.html')
#
# below line is used to title the plot
#
# p=figure(title="test flower")
#
# below lines are used to label label the axis
#
# p.xaxis.axis_label="petal_length"
#
# p.yaxis.axis_label="petal_width"
#
# finally these last two lines are used to built the plot and display it
#
# p.circle(flowers['petal_length'],flowers['petal_width'])
#
# show(p)

# %%
# !pip install bokeh
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
from bokeh.plotting import figure,output_file,show
from bokeh.sampledata.iris import flowers

output_file('test.html')

p=figure(title="test flower")
p.xaxis.axis_label="petal_length"
p.yaxis.axis_label="petal_width"
p.circle(flowers['petal_length'],flowers['petal_width'])
show(p)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   <div class="bk-root" id="fd6e1cd8-438d-4194-b5a6-fd6380f516c8" data-root-id="1002"></div>

# %% [markdown]
# Q2. What are glyphs in Bokeh, and how can you add them to a Bokeh plot? Explain with an example.
# ans:A glyph is a vectorized graphical shape or marker that is used to represent your data.

# %%
#importing Bokeh Libraries
from bokeh.io import output_file
from bokeh.plotting import figure, show

# My x-y coordinate data
x = [1, 2, 1]
y = [1, 1, 2]

# Output the visualization to a static HTML file - first_glyphs.html
output_file('first_glyphs.html', title='First Glyphs')

# Create a figure with no toolbar and axis ranges [0, 3]
fig = figure(title='My Coordinates',
             plot_height=300, plot_width=300,
             x_range=(0, 3), y_range=(0, 3),
             toolbar_location=None)

# Draw the coordinate as circles
fig.circle(x=x, y=y, 
           color='green', size=10, alpha=0.5)

# Show plot 
show(fig)
# Out:
#   <div class="bk-root" id="e0c2c293-0fe9-4c87-ad90-3bc90f37e32f" data-root-id="1222"></div>

# %% [markdown]
# Q3. How can you customize the appearance of a Bokeh plot, including the axes, title, and legend?

# %%
x = [1, 2, 3, 4, 5]
y1 = [4, 5, 5, 7, 2]
y2 = [2, 3, 4, 5, 6]
output_file('line.html')

p = figure(title="Legend example")
p.xaxis.axis_label="x axis"
p.yaxis.axis_label="y axis"
scatter=p.scatter(x,y2,fill_color='red',legend_label='red points',size=10)
line = p.line(x, y1, legend_label="Temp.", line_color="blue", line_width=2)
show(p)
# Out:
#   <div class="bk-root" id="c7bf0b6b-ba18-4b1c-b1e2-49521d013225" data-root-id="1803"></div>

# %% [markdown]
# Q4. What is a Bokeh server, and how can you use it to create interactive plots that can be updated in
# real time?
#
# ans:The Bokeh server is a component of Bokeh that allows you to build interactive web applications that are connected to Python code running on a server. By far the most flexible way to create interactive data visualizations with the Bokeh server is to create Bokeh applications and serve them with the bokeh serve command. The Bokeh server then uses the application code to create sessions and documents for all connecting browsers.

# %% [markdown]
# Q5. How can you embed a Bokeh plot into a web page or dashboard using Flask or Django?
# note:- to be honest this topic was not covered in the lecture (data science hindi) so i don't know how to go about it. I hope there'll be a video uploaded related to this topic so that i can come back and solve this question by myself in future.
